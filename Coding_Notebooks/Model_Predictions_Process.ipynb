# %% [markdown]
# # Model Predictions Process
#
# #### This notebook was used to test the simplest way to generate one prediction from an image that would later be uploaded into an app. My original plan was to figure out how to host an app directly from google colab.
#
# Anvil

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from ultralytics import YOLO
from IPython.display import Image, display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
production_model = YOLO('/content/drive/MyDrive/Projects/Unzipped_Data/25_epochs.pt')

# %%
test_image = '/content/drive/MyDrive/Projects/Unzipped_Data/Denver_Metro_Area_Prediction_Images/Broomfield_3.jpg'
test_result = production_model.predict(test_image, conf=0.2, save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Projects/Unzipped_Data/Denver_Metro_Area_Prediction_Images/Broomfield_3.jpg: 384x640 27 Buildings, 63.5ms
# Speed: 14.0ms preprocess, 63.5ms inference, 48.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict

# %%
test_result_array = test_result[0].plot()
plt.figure(figsize=(16, 16))
plt.imshow(test_result_array)
